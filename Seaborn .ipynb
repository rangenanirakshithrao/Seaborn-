# %%
#Seaborn is a python Library which is used for visulisation purpose
#some main visualising graphs in seaborn are listed below

# %%
# Loading a dataset
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv("Cars2015.csv")

# %%
data
# Out:
#            Make       Model       Type  LowPrice  HighPrice Drive  CityMPG  \
# 0     Chevrolet       Spark  Hatchback    12.270     25.560   FWD       30
# 1       Hyundai      Accent  Hatchback    14.745     17.495   FWD       28
# 2           Kia         Rio      Sedan    13.990     18.290   FWD       28
# 3    Mitsubishi      Mirage  Hatchback    12.995     15.395   FWD       37
# 4        Nissan  Versa Note  Hatchback    14.180     17.960   FWD       31
# ..          ...         ...        ...       ...        ...   ...      ...
# 105      Toyoto     Sequioa      7Pass    44.395     64.320   RWD       12
# 106      Nissan  Pathfinder      7Pass    29.510     43.100   FWD       19
# 107       Acura         MDX      7Pass    42.865     57.080   FWD       18
# 108     Hyundai    Santa Fe      7Pass    30.150     36.000   FWD       18
# 109        GMC        Yukon      7Pass    47.740     67.520   RWD       16
#
# ...

# %%
# Line plot
sns.lineplot(x="Make",y="Type",data=data)
# Out:
# <AxesSubplot:xlabel='Make', ylabel='Type'>

# %%
sns.set(rc={'figure.figsize':(10,5)})
sns.lineplot(x="Length",y="Width",data=data,hue="Size")
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Width'>

# %%
# Scatter Plot
sns.set(rc={'figure.figsize':(20,15)})
sns.scatterplot(x="Size",y="Make",data=data,hue="Drive")
# Out:
# <AxesSubplot:xlabel='Size', ylabel='Make'>

# %%
sns.set(rc={'figure.figsize':(10,5)})
sns.scatterplot(x="CityMPG",y="HwyMPG",data=data,hue="FuelCap")
# Out:
# <AxesSubplot:xlabel='CityMPG', ylabel='HwyMPG'>

# %%
# barplot
sns.set(rc={'figure.figsize':(10,5)})
sns.barplot(x="CityMPG",y="HwyMPG",data=data,hue="Type")
# Out:
# <AxesSubplot:xlabel='CityMPG', ylabel='HwyMPG'>

# %%
# count plot
sns.set(rc={'figure.figsize':(20,10)})
sns.countplot(x="Make",data=data)
# Out:
# <AxesSubplot:xlabel='Make', ylabel='count'>

# %%
# distribution plot
sns.distplot(data["UTurn"])
# Out:
# <AxesSubplot:xlabel='UTurn', ylabel='Density'>

# %%
sns.distplot(data["UTurn"],bins=50,kde=False)
# Out:
# <AxesSubplot:xlabel='UTurn'>

# %%
# pair plot
sns.pairplot(data)

# %%
# joint plot
sns.jointplot(x="CityMPG",y="HwyMPG",data=data,hue="Type")

# %%
# box plot
sns.boxplot(x="Length",y="Width",data=data,hue="Drive")
# Out:
# <AxesSubplot:xlabel='Length', ylabel='Width'>

# %%
# correlation
correlation=data.corr()
sns.heatmap(correlation)
# Out:
# <AxesSubplot:>
